# %% [markdown]
# # development

# %%
import pandas as pd

excel_df = pd.read_excel("wiki_veriler.xlsx")

# %%
excel_df
# Out:
#              isimler                                            linkler  \
# 0      Adsız Aşıklar  https://tr.wikipedia.org/w/index.php?title=Ads...
# 1        Aile Albümü  https://tr.wikipedia.org/w/index.php?title=Ail...
# 2           Alı-Kara  https://tr.wikipedia.org/w/index.php?title=Al%...
# 3              Altay  https://tr.wikipedia.org/w/index.php?title=Alt...
# 4              Arjen  https://tr.wikipedia.org/w/index.php?title=Arj...
# ...              ...                                                ...
# 999        Üvey Baba       https://tr.wikipedia.org/wiki/%C3%9Cvey_Baba
# 1000   Yaprak Dökümü  https://tr.wikipedia.org/wiki/Yaprak_D%C3%B6k%...
# 1001         Yaz Evi              https://tr.wikipedia.org/wiki/Yaz_Evi
# 1002     Yazlıkçılar  https://tr.wikipedia.org/wiki/Yazl%C4%B1k%C3%A...
# 1003  Yılan Hikâyesi  https://tr.wikipedia.org/wiki/Y%C4%B1lan_Hik%C...
#
#      bölüm_adet  sezon_adet durumlar                   yayıncılar
# 0             -         1.0  Yakında                      Netflix
# 1             -         1.0  Yakında                          atv
# 2             -         1.0  Yakında                  Belli değil
# 3             -         1.0  Yakında                        tabii
# 4             -         1.0  Yakında                         GAİN
# ...         ...         ...      ...                          ...
# 999         204         6.0    Final  Star TV / Teleon / Flash TV
# 1000        NaN         NaN    Final                        TRT 1
# 1001        100         3.0    Final                        TRT 1
# 1002         39         6.0    Final              TRT 1 / Star TV
# 1003         90         3.0    Final                      Kanal D
#
# [1004 rows x 6 columns]

# %%
import requests
from bs4 import BeautifulSoup

# Web sayfasının URL'si
url = 'https://tr.wikipedia.org/wiki/Dilek_Ta%C5%9F%C4%B1_(dizi)'

# Sayfayı getir
response = requests.get(url)


html_content = response.text

soup = BeautifulSoup(html_content, 'html.parser')

# %%
info_box = soup.find_all("table", class_ = "infobox")

# %%
info_box
# Out:
# [<table class="infobox" style="vevent"><tbody><tr><th class="infobox-above summary" colspan="2" style="font-style: italic; background: #CCCCFF; padding: 0.25em 1em; line-height: 1.5em;">Dilek Taşı</th></tr><tr><td class="infobox-image" colspan="2"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Dosya:DilekTa%C5%9F%C4%B1.jpg"><img class="mw-file-element" data-file-height="438" data-file-width="350" decoding="async" height="313" src="//upload.wikimedia.org/wikipedia/tr/thumb/5/5a/DilekTa%C5%9F%C4%B1.jpg/250px-DilekTa%C5%9F%C4%B1.jpg" srcset="//upload.wikimedia.org/wikipedia/tr/5/5a/DilekTa%C5%9F%C4%B1.jpg 1.5x" width="250"/></a></span><div class="infobox-caption">Dizinin afişi</div></td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Format</th><td class="infobox-data"><a class="mw-redirect" href="/wiki/Televizyon_dizisi" title="Televizyon dizisi">Televizyon dizisi</a></td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Tür</th><td class="infobox-data"><a href="/wiki/Dram_(sinema_ve_televizyon)" title="Dram (sinema ve televizyon)">Dram</a><br/><a href="/wiki/Tarih%C3%AE_d%C3%B6nem_dramas%C4%B1" title="Tarihî dönem draması">Tarihî</a></td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Proje tasarımcısı</th><td class="infobox-data">Can Sinan</td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Yönetmen</th><td class="infobox-data"><a href="/wiki/Altan_D%C3%B6nmez" title="Altan Dönmez">Altan Dönmez</a> (1-6)<br/>Volkan Kocatürk (7-13)<br/><a href="/wiki/Osman_Ta%C5%9Fc%C4%B1" title="Osman Taşcı">Osman Taşcı</a> (14-)</td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Başrol</th><td class="infobox-data"><a href="/wiki/Salih_Bademci" title="Salih Bademci">Salih Bademci</a><br/><a href="/wiki/Hazal_Suba%C5%9F%C4%B1" title="Hazal Subaşı">Hazal Subaşı</a><br/><a href="/wiki/Ozan_Dolunay" title="Ozan Dolunay">Ozan Dolunay</a></td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Besteci</th><td class="infobox-data">JingleTV</td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Ülke</th><td class="infobox-data"><span class="datasortkey" data-sort-value="Türkiye"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="800" data-file-width="1200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Flag_of_Turkey.svg/23px-Flag_of_Turkey.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Flag_of_Turkey.svg/35px-Flag_of_Turkey.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Flag_of_Turkey.svg/45px-Flag_of_Turkey.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/T%C3%BCrkiye" title="Türkiye">Türkiye</a></span></td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Dili</th><td class="infobox-data"><a href="/wiki/T%C3%BCrk%C3%A7e" title="Türkçe">Türkçe</a></td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Sezon sayısı</th><td class="infobox-data">1</td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Bölüm sayısı</th><td class="infobox-data">16</td></tr><tr><th class="infobox-header" colspan="2" style="background-color:#C6C9FF; padding-top: 2px; padding-bottom: 2px;">Yapım</th></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Yapımcı</th><td class="infobox-data">Yaşar İrvül<br/>Efe İrvül</td></tr><tr><th class="infobox-label" scope="row" style="padding-top: 2px; padding-bottom: 2px;">Mekân</th><td class="infobox-data"><a href="/wiki/%C4%B0stanbul" title="İstanbul">İstanbul</a></td></tr> ...

# %%
rows = (info_box[0].find_all("tr"))

# %%
rows[0].find_all("td")
# Out:
# []

# %%
th_veriler = rows[5].find_all("th")
td_veriler = rows[5].find_all("td")

# %%
td_veriler
# Out:
# [<td class="infobox-data"><a href="/wiki/Altan_D%C3%B6nmez" title="Altan Dönmez">Altan Dönmez</a> (1-6)<br/>Volkan Kocatürk (7-13)<br/><a href="/wiki/Osman_Ta%C5%9Fc%C4%B1" title="Osman Taşcı">Osman Taşcı</a> (14-)</td>]

# %%
director_parts = td_veriler[0].decode_contents().split('<br/>')

names = []

for part in director_parts:
    temp_soup = BeautifulSoup(part, 'html.parser')

    if temp_soup.a:
        names.append(temp_soup.a.text)
    else:
        name = temp_soup.text.split("(")[0].strip()
        names.append(name)

# %%
names
# Out:
# ['Altan Dönmez', 'Volkan Kocatürk', 'Osman Taşcı']

# %%
len(th_veriler), len(td_veriler)
# Out:
# (1, 1)

# %%
dizi_detay_bilgiler = dict()

if len(th_veriler) == 1 and len(td_veriler) == 1:
  dizi_detay_bilgiler[th_veriler[0].text] = td_veriler[0].text

# %%
dizi_detay_bilgiler
# Out:
# {'Yönetmen': 'Altan Dönmez (1-6)Volkan Kocatürk (7-13)Osman Taşcı (14-)'}

# %%
rows[0].find_all("td")
# Out:
# []

# %%
dizi_detay_bilgiler = dict()

for i in range(len(rows)):
    th_veriler = rows[i].find_all("th")
    td_veriler = rows[i].find_all("td")

    if len(th_veriler) == 1 and len(td_veriler) == 1:

        director_parts = td_veriler[0].decode_contents().split('<br/>')
        names = []
        for part in director_parts:
            temp_soup = BeautifulSoup(part, 'html.parser')

            if temp_soup.a:
                names.append(temp_soup.a.text)
            else:
                name = temp_soup.text.split("(")[0].strip()
                names.append(name)

            dizi_detay_bilgiler[th_veriler[0].text] = names

# %%
dizi_detay_bilgiler
# Out:
# {'Format': ['Televizyon dizisi'],
#  'Tür': ['Dram', 'Tarihî'],
#  'Proje tasarımcısı': ['Can Sinan'],
#  'Yönetmen': ['Altan Dönmez', 'Volkan Kocatürk', 'Osman Taşcı'],
#  'Başrol': ['Salih Bademci', 'Hazal Subaşı', 'Ozan Dolunay'],
#  'Besteci': ['JingleTV'],
#  'Ülke': ['Türkiye'],
#  'Dili': ['Türkçe'],
#  'Sezon sayısı': ['1'],
#  'Bölüm sayısı': ['16'],
#  'Yapımcı': ['Yaşar İrvül', 'Efe İrvül'],
#  'Mekân': ['İstanbul'],
#  'Görüntü yönetmeni': ['Hakan Gencan', 'Metin Turguç'],
#  'Gösterim süresi': ['135 dakika'],
#  'Yapım şirketi': ['Pastel Film'],
#  'Kanal': ['Kanal D'],
#  'Resim formatı': ['576i', '1080i'],
#  'Ses formatı': ['Stereo'],
#  'Yayın tarihi': ['7 Eylül 2023 - günümüz'],
#  'Durumu': ['Devam ediyor']}

# %%
for key, value in dizi_detay_bilgiler.items():
    dizi_detay_bilgiler[key] = ', '.join(value)

# Tek satırlık DataFrame oluştur
df = pd.DataFrame([dizi_detay_bilgiler])

# %%
df
# Out:
#               Format           Tür Proje tasarımcısı  \
# 0  Televizyon dizisi  Dram, Tarihî         Can Sinan
#
#                                      Yönetmen  \
# 0  Altan Dönmez, Volkan Kocatürk, Osman Taşcı
#
#                                       Başrol   Besteci     Ülke    Dili  \
# 0  Salih Bademci, Hazal Subaşı, Ozan Dolunay  JingleTV  Türkiye  Türkçe
#
#   Sezon sayısı Bölüm sayısı                 Yapımcı     Mekân  \
# 0            1           16  Yaşar İrvül, Efe İrvül  İstanbul
#
#             Görüntü yönetmeni Gösterim süresi Yapım şirketi    Kanal  \
# 0  Hakan Gencan, Metin Turguç      135 dakika   Pastel Film  Kanal D
#
#   Resim formatı Ses formatı            Yayın tarihi        Durumu
# 0   576i, 1080i      Stereo  7 Eylül 2023 - günümüz  Devam ediyor

# %% [markdown]
# # script

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

excel_df = pd.read_excel("wiki_veriler.xlsx")

# %%
excel_df
# Out:
#              isimler                                            linkler  \
# 0      Adsız Aşıklar  https://tr.wikipedia.org/w/index.php?title=Ads...
# 1        Aile Albümü  https://tr.wikipedia.org/w/index.php?title=Ail...
# 2           Alı-Kara  https://tr.wikipedia.org/w/index.php?title=Al%...
# 3              Altay  https://tr.wikipedia.org/w/index.php?title=Alt...
# 4              Arjen  https://tr.wikipedia.org/w/index.php?title=Arj...
# ...              ...                                                ...
# 999        Üvey Baba       https://tr.wikipedia.org/wiki/%C3%9Cvey_Baba
# 1000   Yaprak Dökümü  https://tr.wikipedia.org/wiki/Yaprak_D%C3%B6k%...
# 1001         Yaz Evi              https://tr.wikipedia.org/wiki/Yaz_Evi
# 1002     Yazlıkçılar  https://tr.wikipedia.org/wiki/Yazl%C4%B1k%C3%A...
# 1003  Yılan Hikâyesi  https://tr.wikipedia.org/wiki/Y%C4%B1lan_Hik%C...
#
#      bölüm_adet  sezon_adet durumlar                   yayıncılar
# 0             -         1.0  Yakında                      Netflix
# 1             -         1.0  Yakında                          atv
# 2             -         1.0  Yakında                  Belli değil
# 3             -         1.0  Yakında                        tabii
# 4             -         1.0  Yakında                         GAİN
# ...         ...         ...      ...                          ...
# 999         204         6.0    Final  Star TV / Teleon / Flash TV
# 1000        NaN         NaN    Final                        TRT 1
# 1001        100         3.0    Final                        TRT 1
# 1002         39         6.0    Final              TRT 1 / Star TV
# 1003         90         3.0    Final                      Kanal D
#
# [1004 rows x 6 columns]

# %%
diziler_detaylar_df = pd.DataFrame()

for i in (range(len(excel_df))):
    print(i, excel_df["isimler"][i])

    link = excel_df["linkler"][i]
    url = link
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, 'html.parser')
    info_box = soup.find_all("table", class_ = "infobox")

    try:
        rows = (info_box[0].find_all("tr"))

        dizi_detay_bilgiler = dict()
        for i in range(len(rows[:20])):
            th_veriler = rows[i].find_all("th")
            td_veriler = rows[i].find_all("td")

            if len(th_veriler) == 1 and len(td_veriler) == 1:

                director_parts = td_veriler[0].decode_contents().split('<br/>')
                names = []
                for part in director_parts:
                    temp_soup = BeautifulSoup(part, 'html.parser')

                    if temp_soup.a:
                        names.append(temp_soup.a.text)
                    else:
                        name = temp_soup.text.split("(")[0].strip()
                        names.append(name)

                dizi_detay_bilgiler[th_veriler[0].text] = names

        for key, value in dizi_detay_bilgiler.items():
            dizi_detay_bilgiler[key] = ', '.join(value)

        df = pd.DataFrame([dizi_detay_bilgiler])
        df.index = [excel_df["isimler"][i]]

        diziler_detaylar_df = pd.concat([diziler_detaylar_df, df], axis = 0)

    except:
        empty_df = pd.DataFrame()
        empty_df.index = [excel_df["isimler"][i]]

        diziler_detaylar_df = pd.concat([diziler_detaylar_df, empty_df], axis = 0)
# Out:
# 0 Adsız Aşıklar
# 1 Aile Albümü
# 2 Alı-Kara
# 3 Altay
# 4 Arjen
# 5 Asaf
# 6 Asya
# 7 Aşk Yarası
# 8 Aşka Düşman
# 9 Aşka Tutsak
# 10 Bahardan Önce
# 11 Beyaz Zambak
# 12 Bi Tuhaf Hikaye
# 13 Bir İhtimal Daha Var
# 14 Bir Sevdadır
# 15 Bizi Seyreden Bulutlar
# 16 Bodrum Hakimi
# 17 Boyacı Kızlar
# 18 Büyük Umutlar
# 19 Çırak
# 20 Çirkin
# 21 Çocuk
# 22 Deha
# 23 Düğüm
# 24 Dünyayı Değiştiren Ayten
# 25 El Turco
# 26 Fatih
# 27 Gaddar
# 28 Gelin
# 29 Güzel Atlar Diyarı
# 30 İnci Taneleri
# 31 İstanbul Ansiklopedisi
# 32 Kara Ağaç
# 33 Kasaba
# 34 Kırmızı Pelerin
# 35 Kimler Geldi, Kimler Geçti
# 36 Kopuk
# 37 Korkma Ben Yanındayım
# 38 Kötü Kan
# 39 Kurtuluş Lisesi
# 40 Kübra
# 41 Mahsun J
# 42 Organize İşler
# 43 Ölüm Kime Yakışır
# 152 Aşk Kumardır
# 153 Aşk ve Umut
# 154 Aşkın Yolculuğu: Hacı Bayram-ı Veli
# 155 Baba
# 156 Balkan Ninnisi
# 157 Barbaros Hayreddin: Sultanın Fermanı
# 158 Ben Bu Cihana Sığmazam
# 159 Ben Gri
# 160 Bir Küçük Gün Işığı
# 161 Bir Peri Masalı
# 162 Canım Annem
# 163 Cezailer
# 164 Çekiç ve Gül: Bir Behzat Ç. Hikayesi
# 165 Çöp Adam
# 166 Darmaduman
# 167 Duran
# 168 Duy Beni
# 169 Dünyayla Benim Aramda
# 170 Erkek Severse
# 171 Erşan Kuneri
# 172 Esaret
# 173 Gecenin Ucunda
# 174 Gelsin Hayat Bildiği Gibi
# 175 Gizli Saklı
# 176 Gül Masalı
# 177 Gülümse Kaderine
# 178 Güzel Günler
# 179 Hakim
# 180 Hayaller ve Hayatlar
# 181 Hayat Bugün
# 182 Hayatımın Şansı
# 183 Hicran
# 184 İçimizdeki Ateş
# 185 İyilik
# 186 Kaçış
# 187 Kadere Karşı
# 188 Kan Çiçekleri
# 189 Kara Tahta
# 190 Kasaba Doktoru
# 191 Kızılcık Şerbeti
# 192 Kıyma
# 193 Kusursuz Kiracı
# <ipython-input-19-21b32c1c93c0>:26: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   temp_soup = BeautifulSoup(part, 'html.parser')
# 194 Kuş Uçuşu
# 195 Mezarlık
# 196 Mükemmel Eşleşme
# 197 Nasıl Fenomen Oldum
# 198 Oğlum
# 199 O Kız
# 200 Pera Palas'ta Gece Yarısı
# 201 Sadece Arkadaşız
# 202 Senden Daha Güzel
# 203 Seni Kalbime Sakladım
# 204 Seversin
# 205 Sevmek Zamanı
# 206 Sıcak Kafa
# 207 Sıfırıncı Gün
# 208 Sipahi
# 209 Sizi Dinliyorum
# 210 Son Nefesime Kadar
# 211 Toprak ile Fidan
# 212 Tozluyaka
# 213 Tuzak
# 214 Uysallar
# 215 Üç Kız Kardeş
# 216 Var Bunlar
# 217 Yakamoz S-245
# 218 Yalı Çapkını
# 219 Yalnız Kurt
# 220 Yazgı
# 221 Yürek Çıkmazı
# 222 Zeytin Ağacı
# 223 50m²
# 224 Acans
# 225 Ada Masalı
# 226 Adım Başı Kafe
# 227 Akıncı
# 228 Alparslan: Büyük Selçuklu
# 229 Annemizi Saklarken
# 230 Aşkın Tarifi
# 231 Aşk Mantık İntikam
# 232 Ayak İşleri
# 233 Aziz
# 234 Babam Çok Değişti
# 235 Baht Oyunu
# 236 Barbaroslar: Akdeniz'in Kılıcı
# 237 Baş Belası
# 238 Benim Hayatım
# 239 Bir Yeraltı Sit-com'u
# 240 Bir Zamanlar Kıbrıs/ Kıbrıs: Zafere Doğru
# 241 Bonkis
# 242 Bozkır Arslanı Celaleddin
# 243 Börü 2039
# 244 Cam Tavanlar
# 245 Camdaki Kız
# 246 Çember
# 247 Destan
# 248 Doğu
# 249 Dünya Hali
# 250 Elkızı
# 251 Elbet Bir Gün
# 252 Evlilik Hakkında Her Şey
# 253 Etkileyici
# 254 Fandom
# 255 Fatma
# 256 Gibi
# 257 Hamlet
# 258 Hiç
# 259 Hükümsüz
# 260 İçimizden Biri
# 261 İkimizin Sırrı
# 262 İlginç Bazı Olaylar
# 263 İlk ve Son
# 264 İşte Bu Benim Masalım
# 265 Kaderimin Oyunu
# 266 Kağıt Ev
# 267 Kalp Yarası
# 268 Kanunsuz Topraklar
# 269 Kardeşlerim
# 270 Kazara Aşk
# 271 Kahraman Babam
# 272 Kırık Hayatlar
# 273 Kulüp
# 274 Leyla ile Mecnun
# 275 Mahkum
# 276 Mahrem
# 277 Maraşlı
# 278 Masumiyet
# 279 Mavera
# 280 Misafir
# 281 Olağan Şüpheliler
# 282 Ölüm Zamanı
# 283 Saklı
# 284 Sana Söz
# 285 Seni Çok Bekledim
# 286 Seyyar
# 287 Sihirli Annem
# 288 Son Yaz
# 289 Şeref Bey
# 290 Teşkilat
# 291 Tozkoparan İskender
# 292 Uzak Şehrin Masalı
# 293 Üç Kuruş
# 294 Vahşi Şeyler
# 295 Yalancı
# 296 Yalancılar ve Mumları
# 297 Yargı
# 298 Yeşilçam
# 299 10 Bin Adım
# 300 Anneler/Acemi Anneler
# 301 Akrep
# 302 Alef
# 303 Alev Alev
# 304 Arıza
# 305 Aşk 101
# 306 İyi Aile Babası
# 307 Babil
# 308 Baraj
# 309 Bay Yanlış
# 310 Bir Annenin Günahı
# 311 Bir Başkadır
# 312 Çatı Katı Aşk
# 313 Çıplak
# 314 Çocukluk
# 315 Emanet
# 316 Ev Yapımı
# 317 Gel Dese Aşk
# 318 Gençliğim Eyvah
# 319 Gönül Dağı
# 320 Hizmetçiler
# 321 İyi Günde Kötü Günde
# 322 Kafa Doktoru
# 323 Kefaret
# 324 Kırmızı Oda
# 325 Maria ile Mustafa
# 326 Masumlar Apartmanı
# 327 Menajerimi Ara
# 328 Öğretmen
# 329 Ramo
# <ipython-input-19-21b32c1c93c0>:26: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   temp_soup = BeautifulSoup(part, 'html.parser')
# 330 Rise of Empires: Ottoman
# 331 Sadakatsiz
# 332 Saygı: Bir Ercüment Çözer Dizisi
# 333 Sen Çal Kapımı
# 334 Sokağın Çocukları
# <ipython-input-19-21b32c1c93c0>:26: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   temp_soup = BeautifulSoup(part, 'html.parser')
# 335 Sol Yanım
# 336 Şaşkın Bakkal 216
# 337 Şeref Sözü
# 338 Tövbeler Olsun
# 339 Tutunamayanlar
# 340 Türkan Hanım'ın Konağı
# 341 Uyanış: Büyük Selçuklu
# 342 Ya İstiklal Ya Ölüm
# 343 Yarım Kalan Aşklar
# 344 Yeni Hayat
# 345 Zemheri
# 346 Zümrüdüanka
# 347 Afili Aşk
# 348 Aşk Ağlatır
# 349 Atiye
# 350 Aynen Aynen
# 351 Azize
# 352 Behzat Ç. Bir Ankara Polisiyesi
# 353 Benim Adım Melek
# 354 Benim Tatlı Yalanım
# 355 Bir Aile Hikayesi
# 356 Canevim
# 357 Çocuk
# 358 Çok Güzel Hareketler 2
# 359 Dengi Dengine
# 360 Doğduğun Ev Kaderindir
# 361 Ferhat ile Şirin
# 362 Güvercin
# 363 Halka
# 364 Hekimoğlu
# <ipython-input-19-21b32c1c93c0>:26: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   temp_soup = BeautifulSoup(part, 'html.parser')
# 365 Her Yerde Sen
# 366 Hercai
# 367 İncir Ağacı
# 368 Kardeş Çocukları
# 369 Kimse Bilmez
# 370 Kurşun
# 371 Kuruluş Osman
# 372 Kuzey Yıldızı İlk Aşk
# 373 Kuzgun
# 374 Leke
# 375 Mucize Doktor
# 376 Nöbet
# 377 Sefirin Kızı
# 378 Sevdim Seni Bir Kere
# 379 Sevgili Geçmiş
# 380 Şampiyon
# 381 Tek Yürek
# 382 Vurgun
# 383 Vuslat
# 384 Yaralı Kuşlar
# 385 Yemin
# 386 Yüzleşme
# 387 Zalim İstanbul
# 388 Zengin ve Yoksul
# 389 4N1K İlk Aşk
# 390 8. Gün
# 391 Ağlama Anne
# 392 Avlu
# 393 Bartu Ben
# 394 Beni Bırakma
# 395 Bir Deli Rüzgar
# 396 Bir Litre Gözyaşı
# 397 Bir Mucize Olsun
# 398 Bir Umut Yeter
# 399 Bir Zamanlar Çukurova
# 400 Bozkır
# 401 Börü
# 402 Can Kırıkları
# 403 Çarpışma
# 404 Darısı Başımıza
# 405 Dip
# 406 Dudullu Postası
# 407 Ege'nin Hamsisi
# 408 Elimi Bırakma
# 409 Erkenci Kuş
# 410 Gülizar
# 411 Gülperi
# 412 Hakan: Muhafız
# 413 Hıçkırık
# 414 İkizler Memo-Can
# 415 İnsanlık Suçu
# 416 Jet Sosyete
# 417 Kalbimin Sultanı
# 418 Kızım
# 419 Koca Koca Yalanlar
# 420 Kocaman Ailem
# 421 Masum Değiliz
# 422 Mehmetçik: Kutlu Zafer
# 423 Mehmetçik: Kut'ül-Amare
# 424 Mehmed: Bir Cihan Fatihi
# 425 Meleklerin Aşkı
# 426 Muhteşem İkili
# 427 Nefes Nefese
# 428 Sen Anlat Karadeniz
# 429 Servet
# 430 Şahin Tepesi
# 431 Şahsiyet
# 432 Tehlikeli Karım
# 433 Tozkoparan
# 434 Yasak Elma
# 435 Yaşamayanlar
# 436 Yuvamdaki Düşman
# 437 7 Yüz
# 438 Adı Efsane
# 439 Aslan Ailem
# 440 Aşk-ı Roman
# 441 Aşk ve Gurur
# 442 Ateşböceği
# 443 Badem Şekeri
# 444 Bahtiyar Ölmez
# 445 Bir Deli Sevda
# 446 Bizim Hikaye
# 447 Bu Şehir Arkandan Gelecek
# 448 Cennet'in Gözyaşları
# 449 Çember
# 450 Çoban Yıldızı
# 451 Çocuklar Duymasın
# 452 Çukur
# 453 Dayan Yüreğim
# 454 Deli Gönül
# 455 Dolunay
# 456 Dostlar Mahallesi
# 457 Evlat Kokusu
# 458 Fazilet Hanım ve Kızları
# 459 Fi
# 460 Hayati ve Diğerleri
# 461 İçimdeki Fırtına
# 462 İki Yalancı
# 463 İkisini de Sevdim
# 464 İsimsizler
# 465 İstanbullu Gelin
# 466 Kadın
# 467 Kalk Gidelim
# 674 Adını Feriha Koydum: Emir'in Yolu
# 675 Ağır Roman Yeni Dünya
# 676 Benim İçin Üzülme
# 677 Bir Zamanlar Osmanlı
# 678 Böyle Bitmesin
# 679 Dila Hanım
# 680 Düşman Kardeşler
# 681 Esir Şehrin Gözyaşları - Bir Ferhat ile Şirin Hikayesi
# 682 Eve Düşen Yıldırım
# 683 Evlerden Biri
# 684 Harem
# 685 Hayatımın Rolü
# 686 Huzur Sokağı
# 687 İbreti Ailem
# 688 İki Dünya Arasında
# 689 İşler Güçler
# 690 Karadayı
# 691 Kayıp Şehir
# 692 Koyu Kırmızı
# 693 Kötü Yol
# 694 Kurt Kanunu
# 695 Küçük Kıyamet
# 696 Merhaba Hayat
# 697 Seksenler
# 698 Son
# 699 Sultan
# 700 Suskunlar
# 701 Şubat
# 702 Türk'ün Uzayla İmtihanı
# 703 Ustura Kemal
# 704 Veda
# 705 Yalan Dünya
# 706 Zengin Kız Fakir Oğlan
# 707 Adını Feriha Koydum
# 708 Al Yazmalım
# 709 Alemin Kralı
# 710 Aşağı Yukarı Yemişlililer
# 711 Avrupa Avrupa
# 712 Beni Affet
# 713 Bir Çocuk Sevdim
# 714 Canan
# 715 Cennetin Sırları
# 716 Dedektif Memoli
# 717 Dinle Sevgili
# 718 Firar
# 719 Hayat Devam Ediyor
# 720 İffet
# 721 İstanbul'un Altınları
# 722 İzmir Çetesi
# 723 Keşanlı Ali Destanı
# 724 Kurşun Bilal
# 725 Kuzey Güney
# 726 Küçük Hanımefendi
# 727 Leyla ile Mecnun
# 728 Mavi Kelebekler
# 729 Mazi Kalbimde Yaradır
# 730 Muhteşem Yüzyıl
# 731 Pis Yedili
# 732 Reis
# 733 Sen de Gitme
# 734 Sihirli Annem
# 735 Tövbeler Tövbesi
# 736 Umutsuz Ev Kadınları
# 737 Üsküdar'a Giderken
# 738 Yamak Ahmet
# 739 Aşk ve Ceza
# 740 Behzat Ç. Bir Ankara Polisiyesi
# 741 Bitmeyen Şarkı
# 742 Çocuklar Duymasın
# 743 Deli Saraylı
# 744 Farklı Desenler
# 745 Fatmagül'ün Suçu Ne?
# 746 Gönül Ferman Dinlemiyor
# 747 Gönülçelen
# 748 Güneydoğudan Öyküler Önce Vatan
# 749 Halil İbrahim Sofrası
# 750 Kader Çizgisi
# 751 Kanıt
# 752 Kızım Nerede?
# 753 Küçük Sırlar
# 754 Küstüm Çiçeği
# 755 Lale Devri
# 756 Öğretmen Kemal
# 757 Öyle Bir Geçer Zaman ki
# 758 Şefkat Tepe
# 759 Şen Yuva
# 760 Türk Malı
# 761 Türkan
# 762 Umut Yolcuları
# 763 Yahşi Cazibe
# 764 Yer Gök Aşk
# 765 Aile Reisi
# 766 Aile Saadeti
# 767 Altın Kızlar
# 768 Aynadaki Düşman
# 769 Ayrılık
# 770 Bir Bulut Olsam
# 771 Bu Kalp Seni Unutur mu?
# 772 Deniz Yıldızı
# 773 Ezel
# 774 Geniş Aile
# 775 Haneler
# 776 Hanımın Çiftliği
# 777 Kahve Bahane
# 778 Kapalıçarşı
# 779 Ritmini Arayan Kalpler
# 780 Kül ve Ateş
# 781 Makber
# 782 Melekler Korusun
# 783 Papatyam
# 784 Sakarya Fırat
# 785 Sıkı Dostlar
# 786 Unutulmaz
# 787 1 Erkek 1 Kadın
# 788 Adanalı
# 789 Akasya Durağı
# 790 Aşk Yakar
# 791 Aşk-ı Memnu
# 792 Aşkım Aşkım
# 793 Baba Ocağı
# 794 Benim Annem Bir Melek
# 795 Bir Varmış Bir Yokmuş
# 796 Canım Ailem
# 797 Cesaretin Var Mı Aşka
# 798 Çok Güzel Hareketler Bunlar
# 799 Doğruluk Ekseni
# 800 Doksandokuz
# 801 Doludizgin Yıllar
# 802 Dur Yolcu
# 803 Emret Komutanım
# 804 Eyvah Halam
# 805 Gece Gündüz
# 806 Görgüsüzler
# 807 Güldünya
# 808 Hepimiz Birimiz İçin
# 809 Kırmızı Işık
# 810 Kollama
# 811 Küçük Kadınlar
# 812 Memur Muzaffer
# 813 Mert ile Gert
# 814 Ölüm Çiçekleri-Saraybosna
# 815 Pars: Narkoterör
# 816 Pulsar
# 817 Süper Babaanne
# 818 Unutma Beni
# 819 Yalancı Romantik
# 820 Yol Arkadaşım
# 821 Annem
# 822 Arka Sıradakiler
# 823 Asi
# 824 Aşk Kapıyı Çalınca
# 825 Bez Bebek
# 826 Bıçak Sırtı
# 827 Dudaktan Kalbe
# 828 Elveda Derken
# 829 Elveda Rumeli
# 830 Fedai
# 831 Fesupanallah
# 832 Geniş Zamanlar
# 833 Genco
# 834 Hakkını Helal Et
# 835 Hayal ve Gerçek
# 836 Hepsi 1
# 837 Karayılan
# 838 Kavak Yelleri
# 839 Komedi Dükkanı
# 840 Kurtlar Vadisi Pusu
# 841 Kurtlar Vadisi Terör
# 842 Kuzey Rüzgârı
# 843 Mahşer-Nabucco'nun Zehri
# 844 Menekşe ile Halil
# 845 Parmaklıklar Ardında
# 846 Sevgili Dünürüm
# 847 Sır Gibi
# 848 Tatlı Bela Fadime
# 849 Tek Türkiye
# 850 Vazgeç Gönlüm
# 851 Yeni Evli
# 852 Yersiz Yurtsuz
# 853 Zeliha'nın Gözleri
# 854 Acemi Cadı
# 855 Adak
# 856 Arka Sokaklar
# 857 Binbir Gece
# 858 Doktorlar
# 859 Fırtına
# 860 Gönül
# 861 Hatırla Sevgili
# 862 Hayat Türküsü
# 863 İki Aile
# 864 Kadın Severse
# 865 Kaybolan Yıllar
# 866 Kınalı Kuzular
# 867 Kırık Kanatlar
# 868 Kod Adı
# 869 Köprü
# 870 Pertev Bey'in Üç Kızı
# 871 Sağır Oda
# 872 Selena
# 873 Sevda Çiçeği
# 874 Sıla
# 875 Yağmurdan Sonra
# 876 Yalancı Yarim
# 877 Yaprak Dökümü
# 878 Yeşeren Düşler
# 879 7 Numara
# 880 Acı Hayat
# 881 Alacakaranlık
# 882 Aliye
# 883 Asmalı Konak
# 884 Aşka Sürgün
# 885 Aşkım Aşkım
# 886 Avrupa Yakası
# 998 Üç İstanbul
# 999 Üvey Baba
# 1000 Yaprak Dökümü
# 1001 Yaz Evi
# 1002 Yazlıkçılar
# 1003 Yılan Hikâyesi

# %%
dizi_detay_bilgiler
# Out:
# {'Format': 'Televizyon dizisi',
#  'Tür': 'Dram, Komedi, Polisiye',
#  'Senarist': 'Tayfun Güneyer',
#  'Yönetmen': 'Nihat Durak',
#  'Başrol': 'Meltem Cumbul, Memet Ali Alabora',
#  'Tema müziği bestecisi': 'Ali Otyam',
#  'Ülke': 'Türkiye',
#  'Dili': 'Türkçe',
#  'Sezon sayısı': '3',
#  'Bölüm sayısı': '90',
#  'Yapımcı': 'Osman Yağmurdereli',
#  'Gösterim süresi': '55 dakika',
#  'Yapım şirketi': 'Yağmur Ajans',
#  'Kanal': 'Kanal D',
#  'Resim formatı': '4:3',
#  'Ses formatı': 'Stereo'}

# %%
diziler_detaylar_df = diziler_detaylar_df.reset_index(drop=True)

# %%
diziler_detaylar_df
# Out:
#                  Format                             Tür    Proje tasarımcısı  \
# 0                   NaN                             NaN                  NaN
# 1                   NaN                             NaN                  NaN
# 2                   NaN                             NaN                  NaN
# 3                   NaN                             NaN                  NaN
# 4                   NaN                             NaN                  NaN
# ...                 ...                             ...                  ...
# 999   Televizyon dizisi                            Dram                  NaN
# 1000  Televizyon dizisi                            Dram  Reşat Nuri Güntekin
# 1001  Televizyon dizisi                        Duygusal                  NaN
# 1002  Televizyon dizisi  Aile, Komedi, Macera, Duygusal                  NaN
# 1003  Televizyon dizisi          Dram, Komedi, Polisiye                  NaN
#
#                                                Senarist  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 999                                          Samim Utku
# 1000                                                NaN
# 1001                                        Nezihe Araz
# 1002  Yalçın Yelence, Umur Bugay, Hakan Haksun, Elva...
# 1003                                     Tayfun Güneyer
#
#                              Yönetmen  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 999                      Tunca Yönder
# 1000                       Ayhan Önal
# 1001  Aram Gülyüz, Naci Çelik Berksoy
# 1002                   Yalçın Yelence
# 1003                      Nihat Durak
#
#                                                  Başrol     Ülke    Dili  \
# 0                                                   NaN      NaN     NaN
# 1                                                   NaN      NaN     NaN
# 2                                                   NaN      NaN     NaN
# 3                                                   NaN      NaN     NaN
# 4                                                   NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 999   Şemsi İnkaya, Betül Aşçıoğlu, Burçin Abdullah,...  Türkiye  Türkçe
# 1000                          Kerim Afşar, Tarık Tarcan  Türkiye  Türkçe
# 1001  Yıldız Kenter, Müşfik Kenter, Şükran Güngör, B...  Türkiye  Türkçe
# 1002  Engin Şenkan, Ayşe Kökçü, Ercan Yazgan, Sıdıka...  Türkiye  Türkçe
# 1003                   Meltem Cumbul, Memet Ali Alabora  Türkiye  Türkçe
#
#      Gösterim süresi                      Kanal  ... Sunucu Kamera Oyuncular  \
# 0                NaN                        NaN  ...    NaN    NaN       NaN
# 1                NaN                        NaN  ...    NaN    NaN       NaN
# 2                NaN                        NaN  ...    NaN    NaN       NaN
# 3                NaN                        NaN  ...    NaN    NaN       NaN
# 4                NaN                        NaN  ...    NaN    NaN       NaN
# ...              ...                        ...  ...    ...    ...       ...
# 999              NaN  Star TV, Teleon, Flash TV  ...    NaN    NaN       NaN
# 1000       45 dakika                      TRT 1  ...    NaN    NaN       NaN
# 1001             NaN                      TRT 1  ...    NaN    NaN       NaN
# 1002             NaN             TRT 1, Star TV  ...    NaN    NaN       NaN
# 1003       55 dakika                    Kanal D  ...    NaN    NaN       NaN
#
#      Cinsi Türü Renk Yapım yılı  Dil    Sonra gelen Önce gelen
# 0      NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 1      NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 2      NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 3      NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 4      NaN  NaN  NaN        NaN  NaN            NaN        NaN
# ...    ...  ...  ...        ...  ...            ...        ...
# 999    NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 1000   NaN  NaN  NaN        NaN  NaN  Yaprak Dökümü        NaN
# 1001   NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 1002   NaN  NaN  NaN        NaN  NaN            NaN        NaN
# 1003   NaN  NaN  NaN        NaN  NaN            NaN        NaN
#
# [1004 rows x 47 columns]

# %%
excel_df
# Out:
#              isimler                                            linkler  \
# 0      Adsız Aşıklar  https://tr.wikipedia.org/w/index.php?title=Ads...
# 1        Aile Albümü  https://tr.wikipedia.org/w/index.php?title=Ail...
# 2           Alı-Kara  https://tr.wikipedia.org/w/index.php?title=Al%...
# 3              Altay  https://tr.wikipedia.org/w/index.php?title=Alt...
# 4              Arjen  https://tr.wikipedia.org/w/index.php?title=Arj...
# ...              ...                                                ...
# 999        Üvey Baba       https://tr.wikipedia.org/wiki/%C3%9Cvey_Baba
# 1000   Yaprak Dökümü  https://tr.wikipedia.org/wiki/Yaprak_D%C3%B6k%...
# 1001         Yaz Evi              https://tr.wikipedia.org/wiki/Yaz_Evi
# 1002     Yazlıkçılar  https://tr.wikipedia.org/wiki/Yazl%C4%B1k%C3%A...
# 1003  Yılan Hikâyesi  https://tr.wikipedia.org/wiki/Y%C4%B1lan_Hik%C...
#
#      bölüm_adet  sezon_adet durumlar                   yayıncılar
# 0             -         1.0  Yakında                      Netflix
# 1             -         1.0  Yakında                          atv
# 2             -         1.0  Yakında                  Belli değil
# 3             -         1.0  Yakında                        tabii
# 4             -         1.0  Yakında                         GAİN
# ...         ...         ...      ...                          ...
# 999         204         6.0    Final  Star TV / Teleon / Flash TV
# 1000        NaN         NaN    Final                        TRT 1
# 1001        100         3.0    Final                        TRT 1
# 1002         39         6.0    Final              TRT 1 / Star TV
# 1003         90         3.0    Final                      Kanal D
#
# [1004 rows x 6 columns]

# %%
kontrol = diziler_detaylar_df.index == excel_df.index

# %%
kontrol
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
len(kontrol)
# Out:
# 1004

# %%
veriseti = pd.concat([excel_df, diziler_detaylar_df], axis = 0)

# %%
diziler_detaylar_df.to_excel("diziler_detaylar_df.xlsx")

# %%
veriseti.to_excel("veriseti.xlsx")
