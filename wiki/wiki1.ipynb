# %%
import requests
from bs4 import BeautifulSoup

# Web sayfasının URL'si
url = 'https://tr.wikipedia.org/wiki/T%C3%BCrk_dizileri_listesi'

# Sayfayı getir
response = requests.get(url)


html_content = response.text

soup = BeautifulSoup(html_content, 'html.parser')

# %%
diziler = soup.find_all("tr")

# %%
isimler, linkler, bölüm_adet, sezon_adet, durumlar, yayıncılar = [], [], [], [], [], []


for dizi in diziler[21:]:

  dizi_veriler = dizi.find_all("td")
  if (len(dizi_veriler)) != 5:
    continue

  adı = dizi_veriler[0].text
  try:
    link = dizi_veriler[0].find("a")["href"]
    link = "https://tr.wikipedia.org" + link
  except:
    continue
  bölüm_sayısı = dizi_veriler[1].text
  sezon_sayısı = dizi_veriler[2].text
  durumu = dizi_veriler[3].text
  yayıncı = dizi_veriler[4].text

  isimler.append(adı.replace("\n", ""))
  linkler.append(link)
  bölüm_adet.append(bölüm_sayısı.replace("\n", ""))
  sezon_adet.append(sezon_sayısı.replace("\n", ""))
  durumlar.append(durumu.replace("\n", ""))
  yayıncılar.append(yayıncı.replace("\n", ""))

# %%
len(isimler), len(linkler), len(bölüm_adet), len(sezon_adet), len(durumlar), len(yayıncılar)
# Out:
# (1004, 1004, 1004, 1004, 1004, 1004)

# %%
import pandas as pd
dataset = pd.DataFrame()

dataset = pd.concat([dataset,
           pd.DataFrame(isimler, columns = ["isimler"]),
           pd.DataFrame(linkler, columns = ["linkler"]),
           pd.DataFrame(bölüm_adet, columns = ["bölüm_adet"]),
           pd.DataFrame(sezon_adet, columns = ["sezon_adet"]),
           pd.DataFrame(durumlar, columns = ["durumlar"]),
           pd.DataFrame(yayıncılar, columns = ["yayıncılar"]),
           ],
          axis = 1)

# %%
dataset
# Out:
#              isimler                                            linkler  \
# 0      Adsız Aşıklar  https://tr.wikipedia.org/w/index.php?title=Ads...
# 1        Aile Albümü  https://tr.wikipedia.org/w/index.php?title=Ail...
# 2           Alı-Kara  https://tr.wikipedia.org/w/index.php?title=Al%...
# 3              Altay  https://tr.wikipedia.org/w/index.php?title=Alt...
# 4              Arjen  https://tr.wikipedia.org/w/index.php?title=Arj...
# ...              ...                                                ...
# 999        Üvey Baba       https://tr.wikipedia.org/wiki/%C3%9Cvey_Baba
# 1000   Yaprak Dökümü  https://tr.wikipedia.org/wiki/Yaprak_D%C3%B6k%...
# 1001         Yaz Evi              https://tr.wikipedia.org/wiki/Yaz_Evi
# 1002     Yazlıkçılar  https://tr.wikipedia.org/wiki/Yazl%C4%B1k%C3%A...
# 1003  Yılan Hikâyesi  https://tr.wikipedia.org/wiki/Y%C4%B1lan_Hik%C...
#
#      bölüm_adet sezon_adet durumlar                   yayıncılar
# 0             -          1  Yakında                      Netflix
# 1             -          1  Yakında                          atv
# 2             -          1  Yakında                  Belli değil
# 3             -          1  Yakında                        tabii
# 4             -          1  Yakında                         GAİN
# ...         ...        ...      ...                          ...
# 999         204          6    Final  Star TV / Teleon / Flash TV
# 1000                          Final                        TRT 1
# 1001        100          3    Final                        TRT 1
# 1002         39          6    Final              TRT 1 / Star TV
# 1003         90          3    Final                      Kanal D
#
# [1004 rows x 6 columns]

# %%
dataset.to_excel("wiki_veriler.xlsx", index = False)
